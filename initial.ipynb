# %%
import pandas as pd

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel('sample.xlsx')

# %%
df
# Out:
#                   event_time event_type  product_id          category_id  \
# 0    2019-10-01 00:00:00 UTC       view    44600062  2103807459595379968
# 1    2019-10-01 00:00:00 UTC       view     3900821  2053013552326769920
# 2    2019-10-01 00:00:01 UTC       view    17200506  2053013559792630016
# 3    2019-10-01 00:00:01 UTC       view     1307067  2053013558920209920
# 4    2019-10-01 00:00:04 UTC       view     1004237  2053013555631879936
# ..                       ...        ...         ...                  ...
# 245  2019-10-01 00:03:29 UTC       view    28717908  2053013565782089984
# 246  2019-10-01 00:03:30 UTC       view    27700106  2053013560086230016
# 247  2019-10-01 00:03:32 UTC       view     4300285  2053013552385489920
# 248  2019-10-01 00:03:32 UTC       view     6200547  2053013552293210112
# 249  2019-10-01 00:03:33 UTC       view     1005115  2053010000000000000
#
#                            category_code         brand    price    user_id  \
# ...

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595379968
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326769920
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792630016
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920209920
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631879936
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_time     250 non-null    object
#  1   event_type     250 non-null    object
#  2   product_id     250 non-null    int64
#  3   category_id    250 non-null    int64
#  4   category_code  170 non-null    object
#  5   brand          224 non-null    object
#  6   price          250 non-null    float64
#  7   user_id        250 non-null    int64
#  8   user_session   250 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 17.7+ KB

# %%
df.isna().sum()
# Out:
# event_time        0
# event_type        0
# product_id        0
# category_id       0
# category_code    80
# brand            26
# price             0
# user_id           0
# user_session      0
# dtype: int64

# %%
# Remove duplicate rows if any
df.drop_duplicates(inplace=True)

# %%
# Fill missing categorical values with 'Unknown'
# df['brand'] = df['brand'].fillna('Unknown')
# df['category_code'] = df['category_code'].fillna('Unknown')

# %%
import numpy as np

# Randomly select 17 indices from the DataFrame
random_indices = np.random.choice(df.index, size=17, replace=False)

# Set those price values to NaN
df.loc[random_indices, 'price'] = np.nan

# %%
df.to_csv('sample.csv', index=False)

# %%
df.isna().sum()
# Out:
# event_time        0
# event_type        0
# product_id        0
# category_id       0
# category_code    80
# brand            26
# price            17
# user_id           0
# user_session      0
# dtype: int64

# %%
df2=pd.read_csv('2019 Oct.csv')
df2
# Out:
#                        event_time event_type  product_id          category_id  \
# 0         2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1         2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2         2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3         2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4         2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
# ...                           ...        ...         ...                  ...
# 42448759  2019-10-31 23:59:58 UTC       view     2300275  2053013560530830019
# 42448760  2019-10-31 23:59:58 UTC       view    10800172  2053013554994348409
# 42448761  2019-10-31 23:59:58 UTC       view     5701038  2053013553970938175
# 42448762  2019-10-31 23:59:59 UTC       view    21407424  2053013561579406073
# 42448763  2019-10-31 23:59:59 UTC       view    13300120  2053013557166998015
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42448764 entries, 0 to 42448763
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 2.8+ GB

# %%
df2.isna().sum()
# Out:
# event_time              0
# event_type              0
# product_id              0
# category_id             0
# category_code    13515609
# brand             6117080
# price                   0
# user_id                 0
# user_session            2
# dtype: int64

# %%
import numpy as np

# Number of missing values to introduce
# num_missing = 1000000  # Example: 1 million

# For user_id
user_id_indices = np.random.choice(df2.index, size=4265082, replace=False)
df2.loc[user_id_indices, 'user_id'] = np.nan

# For price
price_indices = np.random.choice(df2.index, size=319879, replace=False)
df2.loc[price_indices, 'price'] = np.nan

# %%
df2.isna().sum()
# Out:
# event_time              0
# event_type              0
# product_id              0
# category_id             0
# category_code    13515609
# brand             6117080
# price              319879
# user_id           4265082
# user_session            2
# dtype: int64

# %%
# # Number of duplicates to add
# num_duplicates = 82636  # Example: 5 lakh

# # Randomly select rows to duplicate
# duplicate_indices = np.random.choice(df2.index, size=num_duplicates, replace=False)
# duplicates = df2.loc[duplicate_indices]

# # Append duplicates to the DataFrame
# df2 = pd.concat([df2, duplicates], ignore_index=True)

# %%
# Find duplicate rows
duplicates = df2[df2.duplicated()]

# Count total duplicates
num_duplicates = df2.duplicated().sum()

print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 108455

# %%
df2.to_csv('2019 Oct.csv', index=False)
